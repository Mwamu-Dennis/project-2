# %% [markdown]
# PROJECT 2
# NAME:**DENNIS MWAMU**

# %% [markdown]
# 1.DATA UNDERSTANDING

# %% [markdown]
# 1.0)INTRODUCTION
# TITLE:KARAMOJA FOOD YIELD
#
#
# *   Karamoja is a food insecure region in Uganda.
# *   Causes like pests and diseases outbreak and drought cause low productivty levels in the region.
#
# *   Several NGO'S provide technical suport and even farm inputs to the farmers.
# *   Dalberg Data Insghts (DDI) needs to develop a new food security monitory tool to support the decision making of NGO'S in Karamoja.
#
# *   The insight s will be on thwe to major crops that is sorghum and maize in the region.
# *   As a data analyst am required to come up with research  questions and recommendations and also findings on this particular project for DDI

# %% [markdown]
# RESEARCH QUESTIONS
#
#
# *   What is the total crop production per district?
# *   What is the comparison betweeen maize and sorgum production in the district?
#
# *   What is the total crop production per subcounty?
# *   What are some of the best doing districts and also best doing subcounties in roduction of maize and sorghum in the Karamoja region?

# %% [markdown]
# First off is importing the first data set for the district crop yield population

# %%
#upload data in csv format
import pandas as pd
df = pd.read_csv('/content/Uganda_Karamoja_District_Crop_Yield_Population.csv')
df
# Out:
#    OBJECTID           NAME     POP        Area  S_Yield_Ha  M_Yield_Ha  \
# 0        92           ABIM   90385  2771977106         449        1040
# 1        96         AMUDAT  101790  1643582836         205        1297
# 2        20        KAABONG  627057  7373606003         279         945
# 3        85         KOTIDO  243157  3641539808         331        1148
# 4         5         MOROTO  127811  3570160948         128         355
# 5        54  NAKAPIRIPIRIT  146780  4216323900         356        1264
# 6        80          NAPAK  167625  4508782023         137         854
#
#    Crop_Area_Ha     S_Area_Ha    M_Area_Ha  S_Prod_Tot  M_Prod_Tot
# 0   5470.068394   3277.295971  1848.621855     1471506     1922567
# 1   5765.443719   2973.423860  2733.661014      609552     3545558
# 2  28121.672530  20544.194960  7394.416334     5731830     6987723
# 3  53032.649450  50247.443900  1751.372284    16631904     2010575
# ...

# %% [markdown]
# The code below checks the ttal crop production for each particular district

# %%
#total crop production for each particular district
df.groupby('NAME')['Crop_Area_Ha'].sum()
# Out:
# NAME
# ABIM              5470.068394
# AMUDAT            5765.443719
# KAABONG          28121.672530
# KOTIDO           53032.649450
# MOROTO            5954.814048
# NAKAPIRIPIRIT    26372.698490
# NAPAK            22944.296020
# Name: Crop_Area_Ha, dtype: float64

# %% [markdown]
# **DATA CLEANING**

# %% [markdown]
# The code below checks the district with the highest crop area in the region

# %%
#district with the highest crop area
df.loc[df['Crop_Area_Ha'].idxmax()]
# Out:
# OBJECTID                 85
# NAME                 KOTIDO
# POP                  243157
# Area             3641539808
# S_Yield_Ha              331
# M_Yield_Ha             1148
# Crop_Area_Ha    53032.64945
# S_Area_Ha        50247.4439
# M_Area_Ha       1751.372284
# S_Prod_Tot         16631904
# M_Prod_Tot          2010575
# Name: 3, dtype: object

# %% [markdown]
# Checking for the missing values in the dataset

# %%
#null values
df.isnull().sum()
# Out:
# OBJECTID        0
# NAME            0
# POP             0
# Area            0
# S_Yield_Ha      0
# M_Yield_Ha      0
# Crop_Area_Ha    0
# S_Area_Ha       0
# M_Area_Ha       0
# S_Prod_Tot      0
# M_Prod_Tot      0
# dtype: int64

# %% [markdown]
# VISUALIZATIONS FOR THE DISTRICT DATASET

# %% [markdown]
# After some data cleaning we can now do some graphical representations for the districts

# %% [markdown]
# The graph below shows a representation for the district name with the maize total production in Karamoja
# it is clear that Nakapiripit region is producing more maize in the region and Moroto is the least producing reion in  Karamaja region

# %%
#a graphical presentation of the diastrict name and production total of sorghum and maize
import matplotlib.pyplot as plt
df.plot(kind='bar', x='NAME', y='M_Prod_Tot')
plt.show()

# %% [markdown]
# -Kotido region is the largest producer of sorhum in the region.
#
#
#
# -Moroto is the district that produces less sorgumin the region.

# %%
df.plot(kind='bar', x='NAME', y='S_Prod_Tot')
plt.show()

# %% [markdown]
# Below is a representation of the population in the district with Kaabong being the most populated district but does not relate with the crop productions as it does not lead in any but also has large lands.

# %%
#relationship between population and crop production and the district name
df.plot(kind='bar', x='NAME', y='POP')
plt.show()

# %% [markdown]
# **SUBCOUNTY**:Importing the subcounty data

# %%
#uploading another file
df1 = pd.read_csv('/content/Uganda_Karamoja_Subcounty_Crop_Yield_Population.csv')
df1.head()
# Out:
#    OBJECTID       SUBCOUNTY_NAME DISTRICT_NAME    POP        Area Karamoja  \
# 0       263              KACHERI        KOTIDO  17244  1067176155        Y
# 1       264               KOTIDO        KOTIDO  52771   597575188        Y
# 2       265  KOTIDO TOWN COUNCIL        KOTIDO  27389    23972401        Y
# 3       266         NAKAPERIMORU        KOTIDO  38775   419111591        Y
# 4       267           PANYANGARA        KOTIDO  65704   880955930        Y
#
#    S_Yield_Ha   M_Yield_Ha  Crop_Area_Ha     S_Area_Ha   M_Area_Ha  \
# 0  354.207411  1137.467019   7023.533691   6434.342449  528.124229
# 1  367.890523  1162.996687  13587.990760  12455.592640  824.767081
# 2  369.314177  1167.005832   1656.531855   1520.322052    8.561644
# 3  283.324569   852.366578   7087.823334   6761.488901   45.721712
# 4  373.836926  1283.859882  10398.249390  10111.198130  172.611914
#
#      S_Prod_Tot     M_Prod_Tot
# 0  2.279092e+06  600723.892900
# 1  4.582294e+06  959201.382500
# ...

# %% [markdown]
# **DATA CLEANING**

# %% [markdown]
# Checking the last five entries

# %%
df1.tail()
# Out:
#     OBJECTID SUBCOUNTY_NAME  DISTRICT_NAME    POP        Area Karamoja  \
# 47      1029      NGOLERIET          NAPAK  20790   158887552        Y
# 48      1295        NYAKWAE           ABIM  16470   769609687        Y
# 49      1313         LOKOPO          NAPAK  23200  1794470536        Y
# 50      1318           RUPA         MOROTO  41493  2069554899        Y
# 51      1320        MORUITA  NAKAPIRIPIRIT  16588   839293722        Y
#
#     S_Yield_Ha   M_Yield_Ha  Crop_Area_Ha    S_Area_Ha   M_Area_Ha  \
# 47  134.084089   528.699822   1215.227445  1145.339875   68.124005
# 48  329.759030   779.225031    792.898789   342.816838  331.111340
# 49  120.862232   748.829862   6471.047334  5830.549392  553.543123
# 50  114.270921   699.334309   2217.290717  1989.119508  222.838881
# 51  430.557375  1248.955812   1161.390229   185.283445  959.671162
#
#       S_Prod_Tot    M_Prod_Tot
# 47  153571.85410  3.601715e+04
# 48  113046.94800  2.580102e+05
# 49  704693.21440  4.145096e+05
# ...

# %% [markdown]
# Checking for the null values

# %%
#checking for null values in the dataset
df1.isnull().sum()
# Out:
# OBJECTID          0
# SUBCOUNTY_NAME    0
# DISTRICT_NAME     0
# POP               0
# Area              0
# Karamoja          0
# S_Yield_Ha        0
# M_Yield_Ha        0
# Crop_Area_Ha      0
# S_Area_Ha         0
# M_Area_Ha         0
# S_Prod_Tot        0
# M_Prod_Tot        0
# dtype: int64

# %% [markdown]
# Using the (.describe) function to get a summary of the dataset that includes the mean standard variation and other measures

# %%
#calculating the basic summary statistics
df1.describe()
# Out:
#           OBJECTID            POP          Area  S_Yield_Ha   M_Yield_Ha  \
# count    52.000000      52.000000  5.200000e+01   52.000000    52.000000
# mean    787.865385   28934.692308  5.331913e+08  274.165405   940.259552
# std     280.101314   20865.122974  4.913308e+08  118.569907   321.641901
# min     263.000000    1418.000000  2.121209e+06  108.156411     0.000000
# 25%     597.750000   16558.500000  1.568923e+08  173.034066   743.075879
# 50%     810.500000   23053.500000  3.848356e+08  277.255206  1016.684002
# 75%     982.250000   39461.000000  7.749029e+08  368.246437  1203.548665
# max    1320.000000  100919.000000  2.069555e+09  560.313070  1396.991494
#
#        Crop_Area_Ha     S_Area_Ha    M_Area_Ha    S_Prod_Tot    M_Prod_Tot
# count     52.000000     52.000000    52.000000  5.200000e+01  5.200000e+01
# mean    2839.646974   2253.143395   536.300569  6.557443e+05  5.500730e+05
# std     3110.505917   2954.355858   724.092288  9.915839e+05  7.939707e+05
# ...

# %%
df1.columns
# Out:
# Index(['OBJECTID', 'SUBCOUNTY_NAME', 'DISTRICT_NAME', 'POP', 'Area',
#        'Karamoja', 'S_Yield_Ha', 'M_Yield_Ha', 'Crop_Area_Ha', 'S_Area_Ha',
#        'M_Area_Ha', 'S_Prod_Tot', 'M_Prod_Tot'],
#       dtype='object')

# %% [markdown]
# CHECKING THE NUMBER OF ROWS AND COLUMNS IN THE DATASET

# %%
df1.shape
# Out:
# (52, 13)

# %%
#total crop production per subcounty
df1.groupby('SUBCOUNTY_NAME')['Crop_Area_Ha'].sum()
# Out:
# SUBCOUNTY_NAME
# ABIM                            999.371589
# ABIM TOWN COUNCIL               788.462800
# ALEREK                         1266.109868
# AMUDAT                         1651.998420
# AMUDAT TOWN COUNCIL              60.772086
# IRIIRI                         5473.443674
# KAABONG  EAST                  1021.316990
# KAABONG TOWN COUNCIL            175.080527
# KAABONG WEST                    967.336727
# KACHERI                        7023.533691
# KAKOMONGOLE                    3264.534948
# KALAPATA                       2834.349905
# KAMION                          997.161021
# KAPEDO                         2365.259806
# KARITA                         2513.271830
# KATHILE                        6890.699234
# KATIKEKILE                      145.243518
# KAWALAKOL                      3934.432233
# KOTIDO                        13587.990760
# KOTIDO TOWN COUNCIL            1656.531855
# LOBALANGIT                     1890.248613
# ...

# %% [markdown]
# CHECKING THE SUBCOUNTIES WITH THE MOST MAIZE YIELD

# %%
#TOP FIVE SUBCOUNTIES WITH THE MOST MAIZE YIELD
df1.loc[df1['M_Yield_Ha'].nlargest(5).index]
# Out:
#     OBJECTID SUBCOUNTY_NAME  DISTRICT_NAME    POP        Area Karamoja  \
# 19       604          SIDOK        KAABONG  24092   125330583        Y
# 27       812         AMUDAT         AMUDAT  30181   596393139        Y
# 36       980         NAMALU  NAKAPIRIPIRIT  25905   553067364        Y
# 37       981    KAKOMONGOLE  NAKAPIRIPIRIT  15960   312709097        Y
# 17       602         LOYORO        KAABONG  16608  1330019236        Y
#
#     S_Yield_Ha   M_Yield_Ha  Crop_Area_Ha    S_Area_Ha    M_Area_Ha  \
# 19  285.336294  1396.991494    957.493946   859.649027    97.542243
# 27  239.047878  1379.045945   1651.998420   676.783266   972.174246
# 36  560.313070  1325.254872   5793.507623  2197.572106  3293.749460
# 37  398.979005  1318.261936   3264.534948  2791.837410   457.357605
# 17  284.183058  1303.403556   1491.771813  1318.309036   154.682239
#
#       S_Prod_Tot    M_Prod_Tot
# 19  2.452891e+05  1.362657e+05
# 27  1.617836e+05  1.340673e+06
# 36  1.231328e+06  4.365058e+06
# ...

# %%
#average maize yield for the sucounties
df1['M_Yield_Ha'].mean()
# Out:
# 940.2595522519231

# %% [markdown]
# From the above code we can clearly see the average production of maize where most of the subcounties lie.
#
# Then below it we can see a presentation of the statistics

# %%
df1.plot(kind='box', x='SUBCOUNTY_NAME', y='M_Yield_Ha')
plt.figure(figsize=(10,36))
plt.show()

# %%
#average sorghum production
df1['S_Yield_Ha'].mean()
# Out:
# 274.16540509807686

# %%
df1.plot(kind='box', x='SUBCOUNTY_NAME', y='S_Yield_Ha')
plt.figure(figsize=(10,36))

plt.show()

# %% [markdown]
# EXPLANATION
#
# From the two graphs we can see that maize production is more as compared to the production of sorghum.

# %% [markdown]
# Below is a presentation of the population of the subcounties

# %%
df1.plot(kind='bar', x='SUBCOUNTY_NAME', y='POP')
plt.figure(figsize=(10,36))
plt.show()

# %% [markdown]
# JOINING OF THE DATASETS
#
# Now that we have a clear view of the data we can be able to merge them both .
#
# They have some similar relatins like the district names.

# %%
#joining the two data sets
df2 = pd.merge(df,df1, how='outer')
df2.head()
# Out:
# <ipython-input-16-b9520820b1dd>:2: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   df2 = pd.merge(df,df1, how='outer')
#    OBJECTID     NAME     POP        Area  S_Yield_Ha  M_Yield_Ha  \
# 0        92     ABIM   90385  2771977106       449.0      1040.0
# 1        96   AMUDAT  101790  1643582836       205.0      1297.0
# 2        20  KAABONG  627057  7373606003       279.0       945.0
# 3        85   KOTIDO  243157  3641539808       331.0      1148.0
# 4         5   MOROTO  127811  3570160948       128.0       355.0
#
#    Crop_Area_Ha     S_Area_Ha    M_Area_Ha  S_Prod_Tot  M_Prod_Tot  \
# 0   5470.068394   3277.295971  1848.621855   1471506.0   1922567.0
# 1   5765.443719   2973.423860  2733.661014    609552.0   3545558.0
# 2  28121.672530  20544.194960  7394.416334   5731830.0   6987723.0
# 3  53032.649450  50247.443900  1751.372284  16631904.0   2010575.0
# ...

# %%
df2.shape
# Out:
# (59, 14)

# %%
df2.columns
# Out:
# Index(['OBJECTID', 'NAME', 'POP', 'Area', 'S_Yield_Ha', 'M_Yield_Ha',
#        'Crop_Area_Ha', 'S_Area_Ha', 'M_Area_Ha', 'S_Prod_Tot', 'M_Prod_Tot',
#        'SUBCOUNTY_NAME', 'DISTRICT_NAME', 'Karamoja'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# OBJECTID           0
# NAME              52
# POP                0
# Area               0
# S_Yield_Ha         0
# M_Yield_Ha         0
# Crop_Area_Ha       0
# S_Area_Ha          0
# M_Area_Ha          0
# S_Prod_Tot         0
# M_Prod_Tot         0
# SUBCOUNTY_NAME     7
# DISTRICT_NAME      7
# Karamoja           7
# dtype: int64

# %% [markdown]
# After combining the data we can download it in the csv format for it is an excel sheet file .

# %%
#for the combined data , download it in csv format
df2.to_csv('combined_data.csv')

# %% [markdown]
# **FINDINGS**

# %% [markdown]
# from the research the following findings were discovered;
#
# 1)Kotido district had the highest total crop production.
#
# 2)Moroto had the least total crop production followed by Abim.
#
# 3)Nakapiripirit had the highest maize production and Kotido had the highest sorghum production.
#
# 4)At the subcounty level Kotido subcounty had the highrest crop production while Southern Divisio subcounty had the least crop production
#
# 5)Kaabong is the district with the highest population and alspo a large area but he crop production does not match what can be expected of it.

# %% [markdown]
# RECOMMENDATIONS

# %% [markdown]
# -Some scientific researches can be done by the NGO'S to area like Moroto and Abim which are the leat producing districts in Karamoja.
#
# -Kaabong district which has a large population, its large population can be given more farm inputs to ensure that crop production is increased as labour is largely available.
#
# -Kotido district and its subcounties can be given more technical support and also seedlings if needed to ensure that the crop production continues.
#
# -The NGO'S can distribute better and effective pesticides for the crops.
#
# -If possible the NGO'S can dig boreholes for the communities or provide taaped water from rivers or water reservoirs which can adequately boot the crop production in this region.
#
# -The NGO'S can collaborate more with the communities and provide them with the knowledge to tackle such kind of climate and know the best crops to plant which are drought resistant.

# %% [markdown]
# THANK YOU
